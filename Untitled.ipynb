# %%
import pandas as pd

# %%
# Замените "messages.csv" на путь к вашему файлу CSV, если он находится не в текущей директории
df = pd.read_csv("chat_log.csv", encoding='cp1251')

# Отобразим первые несколько строк данных из файла CSV

# Создать новые столбцы
# df['время'] = ''
df[50:70]
# Out:
#    время отправки сообщения                                       сообщение  \
# 50      2024-03-18 14:59:25                    скольким людям ты уже помог?
# 51      2024-03-18 14:59:42                               кто такой кирилл?
# 52      2024-03-18 15:00:02                               а как меня зовут?
# 53      2024-03-18 15:00:22  а про какое имя ты мне только что рассказывал?
# 54      2024-03-18 15:02:46            привет, мое имя егор, как зовут тебя
# 55      2024-03-18 15:03:04                моего первого друга зовут кирилл
# 56      2024-03-18 15:03:16                 моего второго друга зовут артем
# 57      2024-03-18 15:03:27               моего третьего друга зовут сергей
# 58      2024-03-18 15:03:42            моего четвертого друга зовут альберт
# 59      2024-03-18 15:03:53                          как зовут моих друзей?
# 60      2024-03-18 15:04:08                     еще у меня есть друг акакий
# ...
